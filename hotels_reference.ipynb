# %%
 # Import the libraries.
import requests
from bs4 import BeautifulSoup
from requests import get
import pandas as pd
import csv
import matplotlib.pyplot as plt
import time
import random
from google.colab import drive
import re

# %%
# collegamento a google drive
drive.mount('/content/drive')
file_path = "/content/drive/MyDrive/API_completo.csv"
df= pd.read_csv(file_path)
df
# Out:
# Mounted at /content/drive
#                                            attrezzature attrezzature_lingue  \
# 0     Bar,Custodia valori in cassaforte,Parcheggio n...    Francese,Inglese
# 1     Access. diversamente abili parziale,Accesso a ...                 NaN
# 2     Access. diversamente abili parziale,Accettazio...            Francese
# 3     Accesso a mezzi pubblici,Accettazione animali ...    Francese,Inglese
# 4              Accesso a vetture private,Bar,Ristorante                 NaN
# ...                                                 ...                 ...
# 3524  Access. diversamente abili totale,Accesso a me...    Francese,Inglese
# 3525                                                NaN                 NaN
# 3526                                                NaN                 NaN
# 3527  Area attrezzata gioco bimbi,Bar,Parcheggio cus...                 NaN
# 3528                     Accettazione animali domestici                 NaN
#
#       bagni                                       booking_link  camere  \
# 0       1.0  https://www.booking.com/hotel/it/square-apartm...     2.0
# 1       1.0  https://www.booking.com/hotel/it/casa-del-cedr...     1.0
# 2      22.0  https://www.booking.com/hotel/it/genzianella-c...    16.0
# 3       1.0  https://www.booking.com/hotel/it/camera-doppia...     4.0
# 4       1.0  https://www.booking.com/hotel/it/appartamenti-...     2.0
# ...     ...                                                ...     ...
# 3524   25.0                                                NaN    25.0
# 3525    1.0                                                NaN     0.0
# 3526    1.0                                                NaN     0.0
# 3527   14.0                                                NaN     0.0
# 3528    2.0                                                NaN     2.0
#
#           categoria                                    classificazione  \
# 0     Complementari            Locazione turistica non imprenditoriale
# 1     Complementari  Case e appartamenti per vacanze (NON gestiti i...
# 2       Alberghiere                                  Alberghi 3 stelle
# 3     Complementari  Case e appartamenti per vacanze (NON gestiti i...
# 4     Complementari  Case ed appartamenti per vacanze gestiti in fo...
# ...             ...                                                ...
# 3524    Alberghiere                                  Alberghi 3 stelle
# 3525  Complementari  Case e appartamenti per vacanze (NON gestiti i...
# 3526  Complementari  Case e appartamenti per vacanze (NON gestiti i...
# 3527  Complementari  Campeggi e aree attrezzate per camper e roulot...
# 3528  Complementari                                    Bed & Breakfast
#
#      comfort                  denominazione_struttura  \
# 0        8,8                            martini elena
# 1        9,0  cav casa del cedro di salvatore giorgia
# 2        8,8                              genzianella
# 3        8,8                                 milla 9f
# 4        7,7        cav appartamento 6 di casa ideale
# ...      ...                                      ...
# 3524     NaN               HOTEL MILANO (Piazzatorre)
# 3525     NaN                             SINI ALBERTA
# 3526     NaN               ALLA STALLA SUITE & CHALET
# 3527     NaN                      PIAZZATORRE CAMPING
# 3528     NaN                          B&B CA' MORETTI
#
#                               email  ... rating servizi  staff   stato  \
# 0          e.martiniponte@gmail.com  ...    9,2     9,4    9,4  Italia
# 1      casadelcedro.lecco@gmail.com  ...    8,6     8,7    9,4  Italia
# 2             info@hgenzianella.com  ...    8,4     8,5    9,4  Italia
# 3          paolobazzana75@gmail.com  ...    8,3     8,5    9,2  Italia
# 4        casaidealemilano@gmail.com  ...    7,3     7,4    7,4  Italia
# ...                             ...  ...    ...     ...    ...     ...
# 3524         info@hotelmilano.bg.it  ...    NaN     NaN    NaN     NaN
# 3525         alberta.sini@libero.it  ...    NaN     NaN    NaN     NaN
# 3526  studiocolombosrl@legalmail.it  ...    NaN     NaN    NaN     NaN
# 3527   piazzatorrecampingsas@pec.it  ...    NaN     NaN    NaN     NaN
# 3528             albeaely@libero.it  ...    NaN     NaN    NaN     NaN
#
#               tel wifi gratuito      Cap       comune              Indirizzo  \
# 0        30927159           NaN  25056.0       collio         vicolo alpi 10
# 1        30927390            10  23900.0       collio         via marsala 20
# 2     0342 451181           NaN  23023.0       collio         via funivia 31
# 3      3924377232            10  25050.0       collio       via nazionale 10
# 4        30927320           NaN  23900.0       collio         via gorizia 54
# ...           ...           ...      ...          ...                    ...
# 3524   0345 85027           NaN  24010.0  piazzatorre          via centro 19
# 3525   3474233269           NaN  24010.0  piazzatorre  via xx settembre 72/a
# 3526   0363 43156           NaN  24010.0  piazzatorre           via fenile 4
# 3527   0345 85079           NaN  24010.0  piazzatorre     via monte secco 10
# 3528   034 571239           NaN  24010.0  piazzatorre      via iv novembre 2
#
#            Località
# 0     San Colombano
# 1             OLATE
# 2               NaN
# 3     San Colombano
# 4     San Colombano
# ...             ...
# 3524            P 1
# 3525            NaN
# 3526            NaN
# 3527            NaN
# 3528            NaN
#
# [3529 rows x 35 columns]

# %%
# rinomino comune nel dataset api
df = df.rename(columns = {'comune': 'Città'})
df
# Out:
#                                            attrezzature attrezzature_lingue  \
# 0     Bar,Custodia valori in cassaforte,Parcheggio n...    Francese,Inglese
# 1     Access. diversamente abili parziale,Accesso a ...                 NaN
# 2     Access. diversamente abili parziale,Accettazio...            Francese
# 3     Accesso a mezzi pubblici,Accettazione animali ...    Francese,Inglese
# 4              Accesso a vetture private,Bar,Ristorante                 NaN
# ...                                                 ...                 ...
# 3524  Access. diversamente abili totale,Accesso a me...    Francese,Inglese
# 3525                                                NaN                 NaN
# 3526                                                NaN                 NaN
# 3527  Area attrezzata gioco bimbi,Bar,Parcheggio cus...                 NaN
# 3528                     Accettazione animali domestici                 NaN
#
#       bagni                                       booking_link  camere  \
# 0       1.0  https://www.booking.com/hotel/it/square-apartm...     2.0
# 1       1.0  https://www.booking.com/hotel/it/casa-del-cedr...     1.0
# 2      22.0  https://www.booking.com/hotel/it/genzianella-c...    16.0
# 3       1.0  https://www.booking.com/hotel/it/camera-doppia...     4.0
# 4       1.0  https://www.booking.com/hotel/it/appartamenti-...     2.0
# ...     ...                                                ...     ...
# 3524   25.0                                                NaN    25.0
# 3525    1.0                                                NaN     0.0
# 3526    1.0                                                NaN     0.0
# 3527   14.0                                                NaN     0.0
# 3528    2.0                                                NaN     2.0
#
#           categoria                                    classificazione  \
# 0     Complementari            Locazione turistica non imprenditoriale
# 1     Complementari  Case e appartamenti per vacanze (NON gestiti i...
# 2       Alberghiere                                  Alberghi 3 stelle
# 3     Complementari  Case e appartamenti per vacanze (NON gestiti i...
# 4     Complementari  Case ed appartamenti per vacanze gestiti in fo...
# ...             ...                                                ...
# 3524    Alberghiere                                  Alberghi 3 stelle
# 3525  Complementari  Case e appartamenti per vacanze (NON gestiti i...
# 3526  Complementari  Case e appartamenti per vacanze (NON gestiti i...
# 3527  Complementari  Campeggi e aree attrezzate per camper e roulot...
# 3528  Complementari                                    Bed & Breakfast
#
#      comfort                  denominazione_struttura  \
# 0        8,8                            martini elena
# 1        9,0  cav casa del cedro di salvatore giorgia
# 2        8,8                              genzianella
# 3        8,8                                 milla 9f
# 4        7,7        cav appartamento 6 di casa ideale
# ...      ...                                      ...
# 3524     NaN               HOTEL MILANO (Piazzatorre)
# 3525     NaN                             SINI ALBERTA
# 3526     NaN               ALLA STALLA SUITE & CHALET
# 3527     NaN                      PIAZZATORRE CAMPING
# 3528     NaN                          B&B CA' MORETTI
#
#                               email  ... rating servizi  staff   stato  \
# 0          e.martiniponte@gmail.com  ...    9,2     9,4    9,4  Italia
# 1      casadelcedro.lecco@gmail.com  ...    8,6     8,7    9,4  Italia
# 2             info@hgenzianella.com  ...    8,4     8,5    9,4  Italia
# 3          paolobazzana75@gmail.com  ...    8,3     8,5    9,2  Italia
# 4        casaidealemilano@gmail.com  ...    7,3     7,4    7,4  Italia
# ...                             ...  ...    ...     ...    ...     ...
# 3524         info@hotelmilano.bg.it  ...    NaN     NaN    NaN     NaN
# 3525         alberta.sini@libero.it  ...    NaN     NaN    NaN     NaN
# 3526  studiocolombosrl@legalmail.it  ...    NaN     NaN    NaN     NaN
# 3527   piazzatorrecampingsas@pec.it  ...    NaN     NaN    NaN     NaN
# 3528             albeaely@libero.it  ...    NaN     NaN    NaN     NaN
#
#               tel wifi gratuito      Cap        Città              Indirizzo  \
# 0        30927159           NaN  25056.0       collio         vicolo alpi 10
# 1        30927390            10  23900.0       collio         via marsala 20
# 2     0342 451181           NaN  23023.0       collio         via funivia 31
# 3      3924377232            10  25050.0       collio       via nazionale 10
# 4        30927320           NaN  23900.0       collio         via gorizia 54
# ...           ...           ...      ...          ...                    ...
# 3524   0345 85027           NaN  24010.0  piazzatorre          via centro 19
# 3525   3474233269           NaN  24010.0  piazzatorre  via xx settembre 72/a
# 3526   0363 43156           NaN  24010.0  piazzatorre           via fenile 4
# 3527   0345 85079           NaN  24010.0  piazzatorre     via monte secco 10
# 3528   034 571239           NaN  24010.0  piazzatorre      via iv novembre 2
#
#            Località
# 0     San Colombano
# 1             OLATE
# 2               NaN
# 3     San Colombano
# 4     San Colombano
# ...             ...
# 3524            P 1
# 3525            NaN
# 3526            NaN
# 3527            NaN
# 3528            NaN
#
# [3529 rows x 35 columns]

# %%
# open file coordinate geografiche
file_path_3 = '/content/drive/MyDrive/italy_geo.xlsx'

df_geo = pd.read_excel(file_path_3, sheet_name="italy_geo")

# %%
df['Città'] = df['Città'].str.lower()
df_geo['comune'] = df_geo['comune'].str.lower()
# Unione dei dataset basata su "Città" e "Comune" mantenendo solo le righe che sono presenti in "Città"
merged_df = pd.merge(df, df_geo, left_on='Città', right_on='comune', how='inner')

# %%
merged_df = merged_df.drop(['comune', 'istat'], axis=1)

# %%
merged_df
# Out:
#                                            attrezzature attrezzature_lingue  \
# 0     Bar,Custodia valori in cassaforte,Parcheggio n...    Francese,Inglese
# 1     Access. diversamente abili parziale,Accesso a ...                 NaN
# 2     Access. diversamente abili parziale,Accettazio...            Francese
# 3     Accesso a mezzi pubblici,Accettazione animali ...    Francese,Inglese
# 4              Accesso a vetture private,Bar,Ristorante                 NaN
# ...                                                 ...                 ...
# 3524  Access. diversamente abili totale,Accesso a me...    Francese,Inglese
# 3525                                                NaN                 NaN
# 3526                                                NaN                 NaN
# 3527  Area attrezzata gioco bimbi,Bar,Parcheggio cus...                 NaN
# 3528                     Accettazione animali domestici                 NaN
#
#       bagni                                       booking_link  camere  \
# 0       1.0  https://www.booking.com/hotel/it/square-apartm...     2.0
# 1       1.0  https://www.booking.com/hotel/it/casa-del-cedr...     1.0
# 2      22.0  https://www.booking.com/hotel/it/genzianella-c...    16.0
# 3       1.0  https://www.booking.com/hotel/it/camera-doppia...     4.0
# 4       1.0  https://www.booking.com/hotel/it/appartamenti-...     2.0
# ...     ...                                                ...     ...
# 3524   25.0                                                NaN    25.0
# 3525    1.0                                                NaN     0.0
# 3526    1.0                                                NaN     0.0
# 3527   14.0                                                NaN     0.0
# 3528    2.0                                                NaN     2.0
#
#           categoria                                    classificazione  \
# 0     Complementari            Locazione turistica non imprenditoriale
# 1     Complementari  Case e appartamenti per vacanze (NON gestiti i...
# 2       Alberghiere                                  Alberghi 3 stelle
# 3     Complementari  Case e appartamenti per vacanze (NON gestiti i...
# 4     Complementari  Case ed appartamenti per vacanze gestiti in fo...
# ...             ...                                                ...
# 3524    Alberghiere                                  Alberghi 3 stelle
# 3525  Complementari  Case e appartamenti per vacanze (NON gestiti i...
# 3526  Complementari  Case e appartamenti per vacanze (NON gestiti i...
# 3527  Complementari  Campeggi e aree attrezzate per camper e roulot...
# 3528  Complementari                                    Bed & Breakfast
#
#      comfort                  denominazione_struttura  \
# 0        8,8                            martini elena
# 1        9,0  cav casa del cedro di salvatore giorgia
# 2        8,8                              genzianella
# 3        8,8                                 milla 9f
# 4        7,7        cav appartamento 6 di casa ideale
# ...      ...                                      ...
# 3524     NaN               HOTEL MILANO (Piazzatorre)
# 3525     NaN                             SINI ALBERTA
# 3526     NaN               ALLA STALLA SUITE & CHALET
# 3527     NaN                      PIAZZATORRE CAMPING
# 3528     NaN                          B&B CA' MORETTI
#
#                               email  ... staff   stato          tel  \
# 0          e.martiniponte@gmail.com  ...   9,4  Italia     30927159
# 1      casadelcedro.lecco@gmail.com  ...   9,4  Italia     30927390
# 2             info@hgenzianella.com  ...   9,4  Italia  0342 451181
# 3          paolobazzana75@gmail.com  ...   9,2  Italia   3924377232
# 4        casaidealemilano@gmail.com  ...   7,4  Italia     30927320
# ...                             ...  ...   ...     ...          ...
# 3524         info@hotelmilano.bg.it  ...   NaN     NaN   0345 85027
# 3525         alberta.sini@libero.it  ...   NaN     NaN   3474233269
# 3526  studiocolombosrl@legalmail.it  ...   NaN     NaN   0363 43156
# 3527   piazzatorrecampingsas@pec.it  ...   NaN     NaN   0345 85079
# 3528             albeaely@libero.it  ...   NaN     NaN   034 571239
#
#       wifi gratuito      Cap        Città              Indirizzo  \
# 0               NaN  25056.0       collio         vicolo alpi 10
# 1                10  23900.0       collio         via marsala 20
# 2               NaN  23023.0       collio         via funivia 31
# 3                10  25050.0       collio       via nazionale 10
# 4               NaN  23900.0       collio         via gorizia 54
# ...             ...      ...          ...                    ...
# 3524            NaN  24010.0  piazzatorre          via centro 19
# 3525            NaN  24010.0  piazzatorre  via xx settembre 72/a
# 3526            NaN  24010.0  piazzatorre           via fenile 4
# 3527            NaN  24010.0  piazzatorre     via monte secco 10
# 3528            NaN  24010.0  piazzatorre      via iv novembre 2
#
#            Località        lng        lat
# 0     San Colombano  10.333333  45.811167
# 1             OLATE  10.333333  45.811167
# 2               NaN  10.333333  45.811167
# 3     San Colombano  10.333333  45.811167
# 4     San Colombano  10.333333  45.811167
# ...             ...        ...        ...
# 3524            P 1   9.685572  45.990012
# 3525            NaN   9.685572  45.990012
# 3526            NaN   9.685572  45.990012
# 3527            NaN   9.685572  45.990012
# 3528            NaN   9.685572  45.990012
#
# [3529 rows x 37 columns]

# %%
# open file comprensori
file_path_4 = '/content/drive/MyDrive/comprensori_modificato.csv'

df_coordinate = pd.read_csv(file_path_4)

# %%
#estraggo i comuni e li trasformo in un dizionario
comuni = df_coordinate['comune'].drop_duplicates()
city_names = comuni.to_dict()

# %%
# esempio di calcolo della distanza per attribuzione dei punti
from geopy.distance import geodesic
from geopy.geocoders import Nominatim

def get_coordinates(city):
    city = city.lower()  # Converti il nome della città in lettere minuscole
    row = df_geo.loc[df_geo['comune'].str.lower() == city]  # Confronta i nomi delle città in lettere minuscole
    if not row.empty:
        return {
            'latitude': row['lat'].values[0],
            'longitude': row['lng'].values[0]
        }
    else:
        return None

# Estrarre i punti di riferimento dalle città nel dizionario
# Estrarre i punti di riferimento dalle città nel dizionario
reference_points = []
for key, city in city_names.items():
    city = city.lower()  # Converti il nome della città in lettere minuscole
    coordinates = get_coordinates(city)
    if coordinates is not None:
        reference_point = {
            'city': city,  # Aggiungi il nome della città al dizionario
            'latitude': coordinates['latitude'],
            'longitude': coordinates['longitude']
        }
        reference_points.append(reference_point)

        #reference_points.append(coordinates)

# %%
# Funzione per calcolare la distanza geografica tra due punti
def calculate_distance(row, reference_points):
    point = (row['lat'], row['lng'])  # Latitudine e longitudine del record
    distances = []

    for reference_point in reference_points:
        reference_coordinates = (reference_point['latitude'], reference_point['longitude'])  # Latitudine e longitudine del punto di riferimento
        distance = geodesic(point, reference_coordinates).kilometers  # Calcolo della distanza in chilometri
        distances.append(distance)

    min_distance_index = distances.index(min(distances))  # Indice della distanza minima
    nearest_reference = reference_points[min_distance_index]['city']
  # Punto di riferimento più vicino (nome città)

    return nearest_reference

# Aggiunta della colonna "nearest_reference" al DataFrame con il punto di riferimento più vicino
merged_df['nearest_reference'] = merged_df.apply(lambda row: calculate_distance(row, reference_points), axis=1)

# %%
merged_df
# Out:
#                                            attrezzature attrezzature_lingue  \
# 0     Bar,Custodia valori in cassaforte,Parcheggio n...    Francese,Inglese
# 1     Access. diversamente abili parziale,Accesso a ...                 NaN
# 2     Access. diversamente abili parziale,Accettazio...            Francese
# 3     Accesso a mezzi pubblici,Accettazione animali ...    Francese,Inglese
# 4              Accesso a vetture private,Bar,Ristorante                 NaN
# ...                                                 ...                 ...
# 3524  Access. diversamente abili totale,Accesso a me...    Francese,Inglese
# 3525                                                NaN                 NaN
# 3526                                                NaN                 NaN
# 3527  Area attrezzata gioco bimbi,Bar,Parcheggio cus...                 NaN
# 3528                     Accettazione animali domestici                 NaN
#
#       bagni                                       booking_link  camere  \
# 0       1.0  https://www.booking.com/hotel/it/square-apartm...     2.0
# 1       1.0  https://www.booking.com/hotel/it/casa-del-cedr...     1.0
# 2      22.0  https://www.booking.com/hotel/it/genzianella-c...    16.0
# 3       1.0  https://www.booking.com/hotel/it/camera-doppia...     4.0
# 4       1.0  https://www.booking.com/hotel/it/appartamenti-...     2.0
# ...     ...                                                ...     ...
# 3524   25.0                                                NaN    25.0
# 3525    1.0                                                NaN     0.0
# 3526    1.0                                                NaN     0.0
# 3527   14.0                                                NaN     0.0
# 3528    2.0                                                NaN     2.0
#
#           categoria                                    classificazione  \
# 0     Complementari            Locazione turistica non imprenditoriale
# 1     Complementari  Case e appartamenti per vacanze (NON gestiti i...
# 2       Alberghiere                                  Alberghi 3 stelle
# 3     Complementari  Case e appartamenti per vacanze (NON gestiti i...
# 4     Complementari  Case ed appartamenti per vacanze gestiti in fo...
# ...             ...                                                ...
# 3524    Alberghiere                                  Alberghi 3 stelle
# 3525  Complementari  Case e appartamenti per vacanze (NON gestiti i...
# 3526  Complementari  Case e appartamenti per vacanze (NON gestiti i...
# 3527  Complementari  Campeggi e aree attrezzate per camper e roulot...
# 3528  Complementari                                    Bed & Breakfast
#
#      comfort                  denominazione_struttura  \
# 0        8,8                            martini elena
# 1        9,0  cav casa del cedro di salvatore giorgia
# 2        8,8                              genzianella
# 3        8,8                                 milla 9f
# 4        7,7        cav appartamento 6 di casa ideale
# ...      ...                                      ...
# 3524     NaN               HOTEL MILANO (Piazzatorre)
# 3525     NaN                             SINI ALBERTA
# 3526     NaN               ALLA STALLA SUITE & CHALET
# 3527     NaN                      PIAZZATORRE CAMPING
# 3528     NaN                          B&B CA' MORETTI
#
#                               email  ...   stato          tel  wifi gratuito  \
# 0          e.martiniponte@gmail.com  ...  Italia     30927159            NaN
# 1      casadelcedro.lecco@gmail.com  ...  Italia     30927390             10
# 2             info@hgenzianella.com  ...  Italia  0342 451181            NaN
# 3          paolobazzana75@gmail.com  ...  Italia   3924377232             10
# 4        casaidealemilano@gmail.com  ...  Italia     30927320            NaN
# ...                             ...  ...     ...          ...            ...
# 3524         info@hotelmilano.bg.it  ...     NaN   0345 85027            NaN
# 3525         alberta.sini@libero.it  ...     NaN   3474233269            NaN
# 3526  studiocolombosrl@legalmail.it  ...     NaN   0363 43156            NaN
# 3527   piazzatorrecampingsas@pec.it  ...     NaN   0345 85079            NaN
# 3528             albeaely@libero.it  ...     NaN   034 571239            NaN
#
#           Cap        Città              Indirizzo       Località        lng  \
# 0     25056.0       collio         vicolo alpi 10  San Colombano  10.333333
# 1     23900.0       collio         via marsala 20          OLATE  10.333333
# 2     23023.0       collio         via funivia 31            NaN  10.333333
# 3     25050.0       collio       via nazionale 10  San Colombano  10.333333
# 4     23900.0       collio         via gorizia 54  San Colombano  10.333333
# ...       ...          ...                    ...            ...        ...
# 3524  24010.0  piazzatorre          via centro 19            P 1   9.685572
# 3525  24010.0  piazzatorre  via xx settembre 72/a            NaN   9.685572
# 3526  24010.0  piazzatorre           via fenile 4            NaN   9.685572
# 3527  24010.0  piazzatorre     via monte secco 10            NaN   9.685572
# 3528  24010.0  piazzatorre      via iv novembre 2            NaN   9.685572
#
#             lat nearest_reference
# 0     45.811167            collio
# 1     45.811167            collio
# 2     45.811167            collio
# 3     45.811167            collio
# 4     45.811167            collio
# ...         ...               ...
# 3524  45.990012       piazzatorre
# 3525  45.990012       piazzatorre
# 3526  45.990012       piazzatorre
# 3527  45.990012       piazzatorre
# 3528  45.990012       piazzatorre
#
# [3529 rows x 38 columns]

# %%
file_path_merged = '/content/drive/MyDrive/api_merged.csv'

merged_df.to_csv(file_path_merged, index=False)
